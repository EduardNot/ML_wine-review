# %% [markdown]
# ## Machine leaning project
# This project is about wine reviews dataset that was found in Kaggle.
#
# Project team members: Annely Liivas, Velda Lauringson, Eduard Rudi

# %% [markdown]
# #### Importing packages

# %%
import pandas as pd

import gensim
from gensim.models import Word2Vec
from gensim.models import FastText
from autocorrect import Speller
spell = Speller(lang='en')

from statistics import fmean

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.utils import shuffle

# %% [markdown]
# #### Reading data

# %%
lemmatizer = WordNetLemmatizer()
vectorizer = TfidfVectorizer()
word2vec_model = gensim.models.Word2Vec.load('test_word2vec.model')
fastText_model = FastText.load('fastText.model')
stop_words = stopwords.words('english')

# %%
data_loc = 'data/'

# %%
data1 = pd.read_csv(data_loc + 'winemag-data_first150k.csv', index_col=0)
data2 = pd.read_csv(data_loc + 'winemag-data-130k-v2.csv', index_col=0)

# %%
dataset = pd.concat([data1, data2])

# %%
dataset = shuffle(dataset, random_state=123)

# %%
dataset = dataset.reset_index(drop=True)
dataset
# Out:
#             country                                        description  \
# 0                US  Sparkling wine is all about texture, and the m...
# 1            France  This fruity wine, free from any oak aging, rev...
# 2                US  A rich, ripe and complex Cabernet, with classi...
# 3             Italy  Here's a cheerful white blend from Tuscany (wi...
# 4       New Zealand  This medium-weight, supple Pinot Noir is a bit...
# ...             ...                                                ...
# 280896     Portugal  Ripe, rich and creamy, this is a dense wine fr...
# 280897           US  Pretty much a copy of the '03, which I found t...
# 280898           US  The blend is Zinfandel, Syrah, Cabernet Sauvig...
# 280899           US  The aromas of plum, blackberry, vanilla, dried...
# 280900           US  Made from selected lots of Testarossa's variou...
#
#                              designation  points  price       province  \
# 0                                   Brut      85   22.0     California
# 1                                    NaN      85   15.0       Burgundy
# 2                         Estate Bottled      90   35.0     California
# 3                      Fonte delle Donne      87   18.0        Tuscany
# 4                          Estate Series      87   24.0  Central Otago
# ...                                  ...     ...    ...            ...
# 280896                           Reserva      88   12.0          Douro
# 280897  Monte Rosso Vineyard Gnarly Vine      84   50.0     California
# 280898                         Essential      83   11.0     California
# 280899                               NaN      87   14.0     Washington
# 280900                          Niclaire      92   79.0     California
#
#                     region_1          region_2             variety  \
# 0       Russian River Valley            Sonoma     Sparkling Blend
# 1             Mâcon-Villages               NaN          Chardonnay
# 2                Napa Valley              Napa  Cabernet Sauvignon
# 3                    Toscana               NaN         White Blend
# 4                        NaN               NaN          Pinot Noir
# ...                      ...               ...                 ...
# 280896                   NaN               NaN    Portuguese White
# 280897         Sonoma Valley            Sonoma           Zinfandel
# 280898            California  California Other           Red Blend
# 280899  Columbia Valley (WA)   Columbia Valley               Syrah
# 280900            California  California Other          Pinot Noir
#
#                    winery       taster_name taster_twitter_handle  \
# 0              River Road               NaN                   NaN
# 1             Labouré-Roi        Roger Voss            @vossroger
# 2              St. Supéry               NaN                   NaN
# 3       Fattoria Fibbiano               NaN                   NaN
# 4            Matua Valley               NaN                   NaN
# ...                   ...               ...                   ...
# 280896             Borges        Roger Voss            @vossroger
# 280897   Louis M. Martini               NaN                   NaN
# 280898              Bogle               NaN                   NaN
# 280899         Waterbrook  Sean P. Sullivan         @wawinereport
# 280900         Testarossa               NaN                   NaN
#
#                                                    title
# 0                                                    NaN
# 1                       Labouré-Roi 2015  Mâcon-Villages
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 280896                 Borges 2015 Reserva White (Douro)
# 280897                                               NaN
# 280898                                               NaN
# 280899      Waterbrook 2014 Syrah (Columbia Valley (WA))
# 280900  Testarossa 2011 Niclaire Pinot Noir (California)
#
# [280901 rows x 13 columns]

# %%
train = dataset.iloc[:205000]
test = dataset.iloc[205000:]

# %%
# Reset index
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
# For testing
# train = train.iloc[:10000]
# test = test.iloc[:2500]

# %%
#Vaatan, mis toimub
train.head()
# Out:
#        country                                        description  \
# 0           US  Sparkling wine is all about texture, and the m...
# 1       France  This fruity wine, free from any oak aging, rev...
# 2           US  A rich, ripe and complex Cabernet, with classi...
# 3        Italy  Here's a cheerful white blend from Tuscany (wi...
# 4  New Zealand  This medium-weight, supple Pinot Noir is a bit...
#
#          designation  points  price       province              region_1  \
# 0               Brut      85   22.0     California  Russian River Valley
# 1                NaN      85   15.0       Burgundy        Mâcon-Villages
# 2     Estate Bottled      90   35.0     California           Napa Valley
# 3  Fonte delle Donne      87   18.0        Tuscany               Toscana
# 4      Estate Series      87   24.0  Central Otago                   NaN
#
#   region_2             variety             winery taster_name  \
# 0   Sonoma     Sparkling Blend         River Road         NaN
# 1      NaN          Chardonnay        Labouré-Roi  Roger Voss
# 2     Napa  Cabernet Sauvignon         St. Supéry         NaN
# 3      NaN         White Blend  Fattoria Fibbiano         NaN
# 4      NaN          Pinot Noir       Matua Valley         NaN
#
#   taster_twitter_handle                             title
# 0                   NaN                               NaN
# 1            @vossroger  Labouré-Roi 2015  Mâcon-Villages
# 2                   NaN                               NaN
# 3                   NaN                               NaN
# 4                   NaN                               NaN

# %% [markdown]
# #### Preprocessing train description

# %%
reviews_lower = [x.lower() for x in train.description]

# %%
cleaned_reviews = [re.sub('[^a-zA-Z]', ' ', x) for x in reviews_lower]
cleaned_reviews = [re.sub(r'\s+', ' ', x) for x in cleaned_reviews]

# %%
reviews = [nltk.sent_tokenize(x) for x in cleaned_reviews]

# %%
reviews = [y for x in reviews for y in x]

# %%
words = [nltk.word_tokenize(x) for x in reviews]

# %%
for i in range(len(words)):
    words[i] = [lemmatizer.lemmatize(w) for w in words[i] if w not in stop_words and len(lemmatizer.lemmatize(w)) > 1]

# %%
X = vectorizer.fit_transform([' '.join(x) for x in words])

# %%
freq = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
# Out:
# c:\Users\rudi\Desktop\Jupyter Notebook\machine_learning\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
fmean(word2vec_model.wv['wine'] * freq['wine'])
# Out:
# -0.12229394380003214

# %%
desc_score = []
for desc in words:
    word_score = []
    for w in desc:
        # word_score.append(fmean(fastText_model.wv[w]))
        try:
            word_score.append(fmean(word2vec_model.wv[w] * freq[w]))
            # word_score.append(fmean(word2vec_model.wv[w]))
        except:
            # print(f'No word {w}')
            continue
    desc_score.append(fmean(word_score))

# %%
train['desc_score'] = desc_score

# %%
train.head()
# Out:
#        country                                        description  \
# 0           US  Sparkling wine is all about texture, and the m...
# 1       France  This fruity wine, free from any oak aging, rev...
# 2           US  A rich, ripe and complex Cabernet, with classi...
# 3        Italy  Here's a cheerful white blend from Tuscany (wi...
# 4  New Zealand  This medium-weight, supple Pinot Noir is a bit...
#
#          designation  points  price       province              region_1  \
# 0               Brut      85   22.0     California  Russian River Valley
# 1                NaN      85   15.0       Burgundy        Mâcon-Villages
# 2     Estate Bottled      90   35.0     California           Napa Valley
# 3  Fonte delle Donne      87   18.0        Tuscany               Toscana
# 4      Estate Series      87   24.0  Central Otago                   NaN
#
#   region_2             variety             winery taster_name  \
# 0   Sonoma     Sparkling Blend         River Road         NaN
# 1      NaN          Chardonnay        Labouré-Roi  Roger Voss
# 2     Napa  Cabernet Sauvignon         St. Supéry         NaN
# 3      NaN         White Blend  Fattoria Fibbiano         NaN
# 4      NaN          Pinot Noir       Matua Valley         NaN
#
#   taster_twitter_handle                             title  desc_score
# 0                   NaN                               NaN    0.186345
# 1            @vossroger  Labouré-Roi 2015  Mâcon-Villages   -0.286780
# 2                   NaN                               NaN    0.099817
# 3                   NaN                               NaN   -0.207998
# 4                   NaN                               NaN   -0.122666

# %% [markdown]
# #### Preprocessing test description

# %%
reviews_lower = [x.lower() for x in test.description]

# %%
cleaned_reviews = [re.sub('[^a-zA-Z]', ' ', x) for x in reviews_lower]
cleaned_reviews = [re.sub(r'\s+', ' ', x) for x in cleaned_reviews]

# %%
reviews = [nltk.sent_tokenize(x) for x in cleaned_reviews]
reviews = [y for x in reviews for y in x]

# %%
words = [nltk.word_tokenize(x) for x in reviews]

# %%
for i in range(len(words)):
    words[i] = [lemmatizer.lemmatize(w) for w in words[i] if w not in stop_words and len(lemmatizer.lemmatize(w)) > 1]

# %%
desc_score = []
vocab = set(word2vec_model.wv.key_to_index.keys())
for desc in words:
    word_score = []
    for w in desc:
        # word_score.append(fmean(fastText_model.wv[w]))
        
        # try:
        #     word_score.append(fmean(word2vec_model.wv[w] * freq[w]))
        # except:
        #     try:
        #         word_score.append(fmean(word2vec_model.wv[spell(w)] * freq[spell(w)]))
        #     except:
        #         # print(f'No word {w}')
        #         continue
        
        if w in vocab and w in freq:
            word_score.append(fmean(word2vec_model.wv[w] * freq[w]))
            # word_score.append(fmean(word2vec_model.wv[w]))
        elif spell(w) in vocab and spell(w) in freq:
            word_score.append(fmean(word2vec_model.wv[spell(w)] * freq[spell(w)]))
        # else:
        #     try:
        #         word_score.append(fmean(word2vec_model.wv[spell(w)] * freq[spell(w)]))
        #         # word_score.append(fmean(word2vec_model.wv[spell(w)]))
        #     except:
        #         # print(f'No word {w}')
        #         continue
    desc_score.append(fmean(word_score))

# %%
test['desc_score'] = desc_score

# %%
test.head()
# Out:
#    country                                        description designation  \
# 0       US  This is straightforward and easy, with sweet M...         NaN
# 1    Italy  Upfront and generous, this is a bright and foo...       Donia
# 2    Italy  Robust but informal, this opens with aromas of...       Rosso
# 3    Spain  Dusty berry, resin and bell-pepper aromas sugg...     Crianza
# 4  Austria  Beautiful crushed red cherry and lifted, polis...  Vom Kiesel
#
#    points  price        province          region_1 region_2          variety  \
# 0      85   16.0      California       Napa Valley     Napa  Sauvignon Blanc
# 1      86   18.0        Piedmont    Barbera d'Alba      NaN          Barbera
# 2      88   12.0  Southern Italy              Cirò      NaN        Gaglioppo
# 3      89   20.0  Northern Spain  Ribera del Duero      NaN      Tempranillo
# 4      92    NaN      Burgenland               NaN      NaN      St. Laurent
#
#                winery    taster_name taster_twitter_handle  \
# 0            Lola Kay            NaN                   NaN
# 1  Ponchione Maurizio            NaN                   NaN
# 2            Librandi  Kerin O’Keefe          @kerinokeefe
# 3             Tamaral            NaN                   NaN
# 4              Strehn            NaN                   NaN
#
#                                              title  desc_score
# 0      Lola Kay 2011 Sauvignon Blanc (Napa Valley)    0.226332
# 1  Ponchione Maurizio 2007 Donia  (Barbera d'Alba)   -0.117231
# 2                      Librandi 2013 Rosso  (Cirò)   -0.129068
# 3                                              NaN    0.001262
# 4                                              NaN   -0.365299

# %% [markdown]
# ## Encoding columns

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler

# %%
enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
# categories = ['country', 'variety', 'designation', 'province', 'winery']
categories = ['country', 'variety', 'province', 'winery']

# %%
enc.fit(train[categories])
# Out:
# OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

# %%
transformed = enc.transform(train[categories])

# %%
transformed.shape
# Out:
# (205000, 4)

# %%
enc_train = train.copy()

# %%
enc_data = pd.DataFrame(transformed, index=enc_train.index, columns=categories)

# %%
enc_data
# Out:
#         country  variety  province   winery
# 0          46.0    573.0      53.0  14392.0
# 1          16.0    128.0      49.0  10422.0
# 2          46.0     80.0      53.0  15599.0
# 3          23.0    713.0     423.0   7738.0
# 4          33.0    458.0      71.0  11734.0
# ...         ...      ...       ...      ...
# 204995     46.0    128.0      53.0  14861.0
# 204996     46.0    582.0     463.0  11511.0
# 204997     46.0    582.0     463.0  12457.0
# 204998     46.0    128.0     282.0  17695.0
# 204999      1.0    128.0     237.0  14756.0
#
# [205000 rows x 4 columns]

# %%
enc_train = pd.concat([enc_train[['price', 'desc_score', 'points']], enc_data], axis=1)

# %%
enc_train.head()
# Out:
#    price  desc_score  points  country  variety  province   winery
# 0   22.0    0.186345      85     46.0    573.0      53.0  14392.0
# 1   15.0   -0.286780      85     16.0    128.0      49.0  10422.0
# 2   35.0    0.099817      90     46.0     80.0      53.0  15599.0
# 3   18.0   -0.207998      87     23.0    713.0     423.0   7738.0
# 4   24.0   -0.122666      87     33.0    458.0      71.0  11734.0

# %%
enc_train = enc_train.apply(lambda x: x.fillna(int(x.mean())),axis=0)

# %%
test_transformed = enc.transform(test[categories])

# %%
enc_test = test.copy()

# %%
test_enc_data = pd.DataFrame(test_transformed, index=test.index, columns=categories)

# %%
enc_test = pd.concat([enc_test[['price', 'desc_score', 'points']], test_enc_data], axis=1)

# %%
enc_test = enc_test.apply(lambda x: x.fillna(int(x.mean())),axis=0)

# %%
enc_train.to_csv('data/enc_train.csv', index=False)

# %%
enc_test.to_csv('data/enc_test.csv', index=False)
